# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Parts:
# - Part 1: Complete 1 of 3 questions
# - Part 2: Review your partner's Assignment 1 submission
# - Part 3: Perform code review of your partner's assignment 1 by answering the questions below
# - Part 3: Reflect on Assignment 1 and Assignment 2
#
# ## Part 1:
#
# _*You will be assigned one of three problems based of your first name. Enter your first name, in all lower case, execute the code below, and that will tell you your assigned problem. Include the output as part of your submission (do not clear the output). The problems are based-off problems from Leetcode.*_

# %%
import hashlib

def hash_to_range(input_string: str) -> int:
     hash_object = hashlib.sha256(input_string.encode())
     hash_int = int(hash_object.hexdigest(), 16)
     return (hash_int % 3) + 1
input_string = "ivy"
result = hash_to_range(input_string)
print(result)
# Out:
# 2

# %% [markdown]
# <details>
#   <summary>Question 1</summary>
#
#   # Question One: Check Duplicates in Tree
#
#   Given the `root` of a binary tree, check whether it is contains a duplicate value. If a duplicate exists, return the duplicate value. If there are multiple duplicates, return the one with the closest distance to the root. If no duplicate exists, return -1.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: 2
#
#   ### Example 2
#
#   ![](./images/q1_ex2.png)
#
#   Input: `root = [1, 10, 2, 3, 10, 12, 12]`
#
#   Output: 10
#
#   ### Example 3
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 8, 7]`
#
#   Output: -1
#
# </details>
#
# #### Starter Code for Question 1

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def is_duplicate(root: TreeNode) -> int:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 2</summary>
#
#   # Question Two: Path to Leaves
#
#   Given the `root` of a binary tree, return all root to leaf paths in any order.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
#
#   ### Example 2
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 7, 8]`
#
#   Output: [[10, 7], [10, 9, 8]]
#
# </details>
#
# #### Starter Code for Question 2

# %%
from typing import List
# Definition for a binary tree node.
class TreeNode(object):
     def __init__(self, val = 0, left = None, right = None):
         self.val = val
         self.left = left
         self.right = right
def bt_path(root: TreeNode) -> List[List[int]]:

    # 1. Handle the empty tree
    if not root:
        return []
    
    # 2. Handle the leaf node (the end of a path)
    if not root.left and not root.right:
        return [[root.val]]
    
    # 3. Recursive Step: Get paths from children
    paths = []
    
    # Check left side
    for path in bt_path(root.left):
        paths.append([root.val] + path)
        
    # Check right side
    for path in bt_path(root.right):
        paths.append([root.val] + path)
        
    return paths

# %%
#Testing how the code runs

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.right = TreeNode(5)
root.left.left = TreeNode(6)

result = bt_path(root)
print(f"Paths found: {result}")
# Out:
# Paths found: [[1, 2, 6], [1, 2, 5], [1, 3]]

# %% [markdown]
# <details>
#   <summary>Question 3</summary>
#
#   # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[0, n]`. Return a list of numbers that are missing from the range `[0, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [0, 2]`
#
#   Output: [1]
#
#   ### Example 2
#
#   Input: `lst = [5, 0, 1]`
#
#   Output: [2, 3, 4]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 0, 1, 10]`
#
#   Output: [4, 9]
#
# </details>
#
# #### Starter Code for Question 3

# %%
def missing_num(nums: List) -> int:
  # TODO

# %% [markdown]
# ## Part 2:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 3:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %% [markdown]
# My partner's assignment is Question 3. The situation: he is given a list with integers. From the list, his job is to have a newly rearranged list where zeros will now be at the end of the list. If there are no zeros, the order of the integer in the list stays the same.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %% [markdown]
# My new example list=[1,2,3,0,9,0,10]
#     my  output should be [1, 2, 3, 9, 10, 0, 0]
# One of my partner's list is [0, 1, 0, 3, 12]
#     his expected output [1, 3, 12, 0, 0]
#
#     So based on my partner's work, he made a this list and integers inside [0, 1, 0, 3, 12]. Clearly, it is not in the required order of the homework, that is to put all the zeros at the end.
#
#     What he did is run a function called "move_zeros_to_end" so the unordered list can be ordered.
#     The function then keeps a list called "result" that allows only the non-zero integers.
#     It also makes a list called "zeros" to account for the tossed out zeros.
#     Finally it gets the "result" + "zeros"

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
#here is my partner's code: 

from typing import List

def move_zeros_to_end(nums: List[int]) -> List[int]:
    result = [num for num in nums if num != 0]  # keep non-zero elements
    zeros = [0] * (len(nums) - len(result))     # count and add zeros
    return result + zeros

print(move_zeros_to_end([0, 1, 0, 3, 12]))     # [1, 3, 12, 0, 0]
print(move_zeros_to_end([4, 0, 5, 0, 0, 6]))   # [4, 5, 6, 0, 0, 0]
# Out:
# [1, 3, 12, 0, 0]
# [4, 5, 6, 0, 0, 0]

# %% [markdown]
# -   Explain why their solution works in your own words.

# %% [markdown]
# My partner's solution works because first he clearly understood the problem (the expected output is correct). Second, looking at the code, his code clearly accounts for all possible situation by defining a non zero integer list "result" and a separate  "zeros" list.  He finished his function by returning both, where zeros are at the end. This guarantees that the right number of zeros will be tossed to the end.

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %% [markdown]
# THe time complexity of partners is O(n) because the function only looks at all the integers in the list one time and suddenly segregates it. It may pass a few times but constants in Big O are not counted. The space is also O(n) because each integer will only occupy 1 space (either in results or zeros)

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %% [markdown]
# I like my partner's solution its clear and straighforward, make a 2 lists, segragate zero and non zero and put them together.
#
# But maybe another solution he can do is keep the same list,  bumps all the non zero integers to the front leaving all the zeros at the end. This is better instead of sorting each integer to "result" or "zero" group. This will improve the time and space complexity to O(1) from O(n) because the list is the same. No need to make new lists.

# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %% [markdown]
# At the start of the lesson I am having a hard time grasping the concept of the Big O. Although I have strong understanding of various math function, to tie it to a time and space complexity took time. As soon as we discuss about various data structure, i calmed down.
#
# This homework solidified my understanding as well as my appreciation in Data Mining. Here are the main points.
#
# I call my assignment 1 the pringles can and the use of Stack (an ADT). My problem asked me to know if the brackets I am given (later, an made example) is valid or not. Simply, the validity requires it to 1: have a partner and 2: correct nesting.
#
# Using Stack, everytime i draw a open bracket, i drop it to the can. I keep on getting the closer and if it pair with the opener on top, they have found a pair and they will exit the can. I recursively do this till all the openers have found its partner and the solution is valid. If there is an unpaired bracket left, it is invalid.
#
# For the review of my partner, it is my first time reviewing other's work. This time I had to understand what his solution was. After going through the lectures and ADT structure as well as my assignment 1, I actually enjoyed critiquing my partner's work. I am amazed at how his solution but more so, I realized that there is an alternative way. As the saying goes, there are a thousand ways to skin a cat ( or something like that).
#
# Finally, I love the way this homework was conducted. For a rigorous and serious (and very useful) topic, I get to critique and write a review and learn at the same time. It makes me appreciate way more and now, I am excited to learn. I though production was exciting but this too is exciting. Thank you Salaar and to the learning team! Please continue what you do.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-6-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
